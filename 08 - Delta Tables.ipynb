# %%
# %%sql
#
# SELECT * FROM city_safety_seattle
# Out:
# StatementMeta(, 528724ca-26ae-403f-96e1-63bd1aa0f7b0, 2, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 11 fields>

# %%
# %%pyspark
# spark.conf.get('spark.sql.parquet.vorder.enabled')
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit

df = spark.sql("DESCRIBE DETAIL city_safety_seattle")

display(df)
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
# %%sql
#
# UPDATE city_safety_seattle
# SET Source = 1
# WHERE YEAR(dateTime) = 2005
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
# %%sql
#
# DESCRIBE HISTORY city_safety_seattle
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
df = spark.read.format("delta").option("Version", "1").table("city_safety_seattle")
df.show()
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
changes = spark.read.format("delta") \
    .option("readChangeData", "true") \
    .option("startingVersion", 4) \
    .option("endingVersion", 5) \
    .table("city_safety_seattle")

display(changes)
# Out:
# StatementMeta(, ed73bb94-5fce-44a4-80b1-77f4546753fa, 31, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c6c2d581-b1ac-4aca-9646-bbbbc0a38ae3)

# %%
# %%sql
#
# /* ALTER TABLE city_safety_seattle SET TBLPROPERTIES (delta.enableChangeDataFeed=true) */
# Out:
# StatementMeta(, ed73bb94-5fce-44a4-80b1-77f4546753fa, 25, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# /* OPTIMIZE city_safety_seattle */

# %%
# %%sql
#
# /* VACUUM city_safety_seattle RETAIN 500 HOURS */
