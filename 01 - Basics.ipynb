# %% [markdown]
# # Basics

# %%
print("Hello Hanau")
# Out:
# StatementMeta(, 585f58ae-7c1d-4dca-8edd-a517434ea035, 3, Finished, Available, Finished)
# Hello Hanau

# %%
print(f"Let's calculate 1 + 1 = {1+1}")
# Out:
# StatementMeta(, 585f58ae-7c1d-4dca-8edd-a517434ea035, 4, Finished, Available, Finished)
# Let's calculate 1 + 1 = 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Generate some random data
num_points = 20
# x will be 5, 6, 7... but also twiddled randomly
x = 5 + np.arange(num_points) + np.random.randn(num_points)
# y will be 10, 11, 12... but twiddled even more randomly
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)
sns.regplot(x=x, y=y)
plt.show()
# Out:
# StatementMeta(, 585f58ae-7c1d-4dca-8edd-a517434ea035, 5, Finished, Available, Finished)

# %% [markdown]
# # 🌟 Welcome to the World of Markdown! 🌟
#
# Markdown allows you to create **well-structured** and **aesthetic** documents. Here’s a creative demonstration:
#
# ---
#
# ## **Headings and Text Formatting**
#
# You can use **bold text**, *italic text*, or ~~strikethrough text~~.
#
# > This is a blockquote for special emphasis.
#
# ---
#
# ## **Lists and Tables**
#
# ### Unordered List:
# - Python
# - Jupyter
# - Markdown
#
# ### Ordered List:
# 1. Write code
# 2. Analyze data
# 3. Draw diagrams
#
# ---
#
# ### **Table of the Coolest Programming Languages:**
#
# | Programming Language | Popularity | Use Cases                 |
# |----------------------|------------|---------------------------|
# | Python               | ⭐⭐⭐⭐⭐      | Data Science, Web, ML      |
# | JavaScript           | ⭐⭐⭐⭐       | Web Development, Frontend  |
# | C++                  | ⭐⭐⭐        | High-Performance Computing |
#
# ---

# %% [markdown]
# # ipywidgets
#
#
# ipywidgets are interactive HTML widgets used in Jupyter Notebooks to create user interfaces that interact with Python code. They allow for dynamic inputs like sliders, dropdowns, and buttons to execute code interactively and display results visually.

# %%
import ipywidgets as widgets
from IPython.display import display

# Numeric Widgets
int_slider = widgets.IntSlider(description="IntSlider", min=0, max=100, value=50)
float_slider = widgets.FloatSlider(description="FloatSlider", min=0, max=1, value=0.5)
int_range_slider = widgets.IntRangeSlider(description="IntRangeSlider", min=0, max=100, value=(25, 75))
float_range_slider = widgets.FloatRangeSlider(description="FloatRangeSlider", min=0, max=1, value=(0.25, 0.75))
int_progress = widgets.IntProgress(description="IntProgress", value=50, min=0, max=100)
float_progress = widgets.FloatProgress(description="FloatProgress", value=0.5, min=0, max=1)
# bounded_int_text = widgets.BoundedIntText(description="BoundedIntText", min=0, max=100, value=50)
# bounded_float_text = widgets.BoundedFloatText(description="BoundedFloatText", min=0, max=1, value=0.5)
# int_text = widgets.IntText(description="IntText", value=50)
# float_text = widgets.FloatText(description="FloatText", value=0.5)

# Boolean Widgets
# toggle_button = widgets.ToggleButton(description="ToggleButton", value=False)
# checkbox = widgets.Checkbox(description="Checkbox", value=False)
# valid = widgets.Valid(value=True)

# Selection Widgets
# dropdown = widgets.Dropdown(description="Dropdown", options=["Option 1", "Option 2", "Option 3"], value="Option 1")
# radio_buttons = widgets.RadioButtons(description="RadioButtons", options=["Option 1", "Option 2", "Option 3"], value="Option 1")
# select = widgets.Select(description="Select", options=["Option 1", "Option 2", "Option 3"], value="Option 1")
# selection_slider = widgets.SelectionSlider(description="SelectionSlider", options=["Low", "Medium", "High"], value="Medium")
# selection_range_slider = widgets.SelectionRangeSlider(description="RangeSlider", options=["Low", "Medium", "High"], value=("Low", "High"))
# toggle_buttons = widgets.ToggleButtons(description="ToggleButtons", options=["Option 1", "Option 2", "Option 3"], value="Option 1")
# select_multiple = widgets.SelectMultiple(description="SelectMultiple", options=["Option 1", "Option 2", "Option 3"], value=["Option 1"])

# String Widgets
# text = widgets.Text(description="Text", value="Enter text")
# textarea = widgets.Textarea(description="Textarea", value="Enter multiple lines")
# html = widgets.HTML(value="<b>HTML</b> Example")
# html_math = widgets.HTMLMath(value="E=mc^2")
# label = widgets.Label(value="Label Example")

# Date and Time Widgets
date_picker = widgets.DatePicker(description="DatePicker")

# Button Widget
# button = widgets.Button(description="Click Me")

# Output Widget
output = widgets.Output()

# Layout Widgets
# hbox = widgets.HBox([int_slider, float_slider])
# vbox = widgets.VBox([dropdown, text])
# grid_box = widgets.GridBox(children=[int_slider, float_slider, checkbox], layout=widgets.Layout(grid_template_columns="repeat(3, 200px)"))
# accordion = widgets.Accordion(children=[text, textarea])
# accordion.set_title(0, 'Text Input')
# accordion.set_title(1, 'Textarea Input')
# tab = widgets.Tab(children=[text, textarea])
# tab.set_title(0, 'Text')
# tab.set_title(1, 'Textarea')

# Play widget
play = widgets.Play(
    value=50,
    min=0,
    max=100,
    step=1,
    description="Press play"
)

# Display Widgets
display(int_slider, float_slider, int_range_slider, float_range_slider, int_progress, float_progress)
#display(bounded_int_text, bounded_float_text, int_text, float_text)
#display(toggle_button, checkbox, valid)
#display(dropdown, radio_buttons, select, selection_slider, selection_range_slider, toggle_buttons, select_multiple)
#display(text, textarea, html, html_math, label)
#display(date_picker, button, output)
#display(hbox, vbox, grid_box, accordion, tab, play)
# Out:
# StatementMeta(, e5d377bd-9d4c-48d7-89ea-5c86b4d74710, 6, Finished, Available, Finished)
# IntSlider(value=50, description='IntSlider')
# FloatSlider(value=0.5, description='FloatSlider', max=1.0)
# IntRangeSlider(value=(25, 75), description='IntRangeSlider')
# FloatRangeSlider(value=(0.25, 0.75), description='FloatRangeSlider', max=1.0)
# IntProgress(value=50, description='IntProgress')
# FloatProgress(value=0.5, description='FloatProgress', max=1.0)

# %%
import ipywidgets as widgets
from IPython.display import display
import time

# Erstelle das IntProgress-Widget
progress = widgets.IntProgress(value=0, min=0, max=100, description='Loading:', bar_style='info')

# Zeige das Widget an
display(progress)

# Schleife von 1 bis 100 mit 0,5 Sekunden Wartezeit pro Schritt
for i in range(1, 101):
    progress.value = i
    time.sleep(0.2)  # Warte 0,5 Sekunden
# Out:
# StatementMeta(, e5d377bd-9d4c-48d7-89ea-5c86b4d74710, 9, Finished, Available, Finished)
# IntProgress(value=0, bar_style='info', description='Loading:')
# StatementMeta(, e5d377bd-9d4c-48d7-89ea-5c86b4d74710, 10, Finished, Available, Finished)

# %% [markdown]
# ## Mermaid
#
# Currently, Mermaid is not directly supported by Notebooks, unlike VSCode.
# However, it can be used with a small detour.

# %%
import base64
from IPython.display import Image, display
import matplotlib.pyplot as plt

def mm(graph):
    graphbytes = graph.encode("utf8")
    base64_bytes = base64.urlsafe_b64encode(graphbytes)
    base64_string = base64_bytes.decode("ascii")
    display(Image(url="https://mermaid.ink/img/" + base64_string))
mm("""
graph LR;
    A--> B & C & D;
    B--> A & E;
    C--> A & E;
    D--> A & E;
    E--> B & C & D;
""")
# Out:
# StatementMeta(, 4691928a-e77c-4a66-aef2-a1422d15d893, 54, Finished, Available, Finished)
# <img src="https://mermaid.ink/img/CmdyYXBoIExSOwogICAgQS0tPiBCICYgQyAmIEQ7CiAgICBCLS0-IEEgJiBFOwogICAgQy0tPiBBICYgRTsKICAgIEQtLT4gQSAmIEU7CiAgICBFLS0-IEIgJiBDICYgRDsK"/>
