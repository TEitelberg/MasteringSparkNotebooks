# %%
df = spark.sql("SELECT * FROM Lakehouse.dbo.city_safety_seattle LIMIT 1000")

# %%
df.show()

# %%
config_data = spark.sparkContext.getConf().getAll()
config_df = spark.createDataFrame(config_data, ['Parameter', 'Value'])
config_df.show(truncate=False)

# %%
import sempy

sempy.fabric.list_items()
