# %%
df = spark.read.format("csv").option("header","true").load("Files/sample_datasets/ImmoScout24_CH_Rental_Property_Dataset.csv")
# df now is a Spark DataFrame containing CSV data from "Files/sample_datasets/ImmoScout24_CH_Rental_Property_Dataset.csv".
display(df)
# Out:
# StatementMeta(, c35f425e-55e1-43cb-bfc9-84755ac643ae, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 58a5899b-ab32-46dd-a49e-d50bacd43612)
